# %% [markdown]
# # <font color = red> Problema 3: 8/10
#
# <font color = red> Comentarios: 1) Se les pedía la generación 6? (-1 punto) 2) No corre, cuidado (-1 punto)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def Squares(x1,y1,L,n):
    '''
        x1,y1: coordenadas del vertice izquierdo L: longitud del triangulo a subdividir 
        n: número de interaciones
    '''
   
    if  n>0:
        kno=np.random.randint(4,size=1)
        

        for k in range (4):
            if k!=kno:
                i= k%2
                j= k//2
                x=x1+i*L/2
                y=y1+j*L/2
                Squares(x,y,L/2,n-1)
        
        
    else:
        cuadrado = plt.Rectangle((x1, y1),L,L,color='r')
        ax.add_patch(cuadrado)

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1, 1, 1)
ax.set_xlim(0,600)
ax.set_ylim(0,600)
ax.set_xticks([])
ax.set_yticks([])
n = 9 # PROFESOR: Colocado  por RPV
Squares(0,0,600,n)
#fig.savefig("Squares"+str(r)+".png") # PROFESOR: Comentado por RPV
plt.show()

# %% [markdown]
# ## La dimensión fractal es la siguiente debido a que la longitud de divide en 2 cada vez y se generan tres cuadros^n  por cada n generación

# %% [markdown]
# ![image.png](attachment:image.png)

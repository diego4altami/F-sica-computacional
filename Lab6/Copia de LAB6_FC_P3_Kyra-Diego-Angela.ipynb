# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def SierpinskiGasket(x1,y1,L,n):
    '''
        x1,y1: coordenadas del vertice izquierdo L: longitud del triangulo a subdividir 
        n: número de interaciones
    '''
    if n>0:
        x2 = x1 + L/2
        y2 = y1
        x3 = x1 + L/4
        y3 = y1 + np.sqrt(3)*L/4

        SierpinskiGasket(x1,y1,L/2,n-1)
        SierpinskiGasket(x2,y2,L/2,n-1)
        SierpinskiGasket(x3,y3,L/2,n-1)
    else:
        triangulo = plt.Polygon([[x1, y1], [x1+L, y1], [x1+L/2, y1+np.sqrt(3)*L/2]],color='g')
        ax.add_patch(triangulo)

# %%
fig = plt.figure(figsize=(16,16))
ax = fig.add_subplot(1, 1, 1)
ax.set_xlim(0,600)
ax.set_ylim(0,600)
ax.set_xticks([])
ax.set_yticks([])
r = 102
SierpinskiGasket(0,0,600,r)
fig.savefig("SierpinskiGasket"+str(r)+".png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/1594783440.py in <module>
#       6 ax.set_yticks([])
#       7 r = 102
# ----> 8 SierpinskiGasket(0,0,600,r)
#       9 fig.savefig("SierpinskiGasket"+str(r)+".png")
#      10 plt.show()
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      11
#      12         SierpinskiGasket(x1,y1,L/2,n-1)
# ---> 13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#      15     else:
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      11
#      12         SierpinskiGasket(x1,y1,L/2,n-1)
# ---> 13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#      15     else:
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
# ---> 14         SierpinskiGasket(x3,y3,L/2,n-1)
#      15     else:
#      16         triangulo = plt.Polygon([[x1, y1], [x1+L, y1], [x1+L/2, y1+np.sqrt(3)*L/2]],color='g')
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      10         y3 = y1 + np.sqrt(3)*L/4
#      11
# ---> 12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      11
#      12         SierpinskiGasket(x1,y1,L/2,n-1)
# ---> 13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#      15     else:
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
# ---> 14         SierpinskiGasket(x3,y3,L/2,n-1)
#      15     else:
#      16         triangulo = plt.Polygon([[x1, y1], [x1+L, y1], [x1+L/2, y1+np.sqrt(3)*L/2]],color='g')
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
# ---> 14         SierpinskiGasket(x3,y3,L/2,n-1)
#      15     else:
#      16         triangulo = plt.Polygon([[x1, y1], [x1+L, y1], [x1+L/2, y1+np.sqrt(3)*L/2]],color='g')
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      11
#      12         SierpinskiGasket(x1,y1,L/2,n-1)
# ---> 13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#      15     else:
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      11
#      12         SierpinskiGasket(x1,y1,L/2,n-1)
# ---> 13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#      15     else:
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      11
#      12         SierpinskiGasket(x1,y1,L/2,n-1)
# ---> 13         SierpinskiGasket(x2,y2,L/2,n-1)
#      14         SierpinskiGasket(x3,y3,L/2,n-1)
#      15     else:
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      12         SierpinskiGasket(x1,y1,L/2,n-1)
#      13         SierpinskiGasket(x2,y2,L/2,n-1)
# ---> 14         SierpinskiGasket(x3,y3,L/2,n-1)
#      15     else:
#      16         triangulo = plt.Polygon([[x1, y1], [x1+L, y1], [x1+L/2, y1+np.sqrt(3)*L/2]],color='g')
#
# /var/folders/jb/60_98sg10y12km6nlm43yctc0000gn/T/ipykernel_99201/2992226869.py in SierpinskiGasket(x1, y1, L, n)
#      15     else:
#      16         triangulo = plt.Polygon([[x1, y1], [x1+L, y1], [x1+L/2, y1+np.sqrt(3)*L/2]],color='g')
# ---> 17         ax.add_patch(triangulo)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in add_patch(self, p)
#    2361         if p.get_clip_path() is None:
#    2362             p.set_clip_path(self.patch)
# -> 2363         self._update_patch_limits(p)
#    2364         self._children.append(p)
#    2365         p._remove_method = self._children.remove
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in _update_patch_limits(self, patch)
#    2394             if updatey and patch_trf == self.get_xaxis_transform():
#    2395                 updatey = False
# -> 2396         trf_to_data = patch_trf - self.transData
#    2397         xys = trf_to_data.transform(vertices)
#    2398         self.update_datalim(xys, updatex=updatex, updatey=updatey)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/transforms.py in __sub__(self, other)
#    1457             return NotImplemented
#    1458         for remainder, sub_tree in self._iter_break_from_left_to_right():
# -> 1459             if sub_tree == other:
#    1460                 return remainder
#    1461         for remainder, sub_tree in other._iter_break_from_left_to_right():
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/transforms.py in __eq__(self, other)
#    2395     def __eq__(self, other):
#    2396         if isinstance(other, (CompositeGenericTransform, CompositeAffine2D)):
# -> 2397             return self is other or (self._a == other._a
#    2398                                      and self._b == other._b)
#    2399         else:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/transforms.py in __eq__(self, other)
#    1725
#    1726     def __eq__(self, other):
# -> 1727         return self._child.__eq__(other)
#    1728
#    1729     __str__ = _make_str_method("_child")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/transforms.py in __eq__(self, other)
#    2168             return (self._x == other._x) and (self._y == other._y)
#    2169         elif self._x == self._y:
# -> 2170             return self._x == other
#    2171         else:
#    2172             return NotImplemented
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/transforms.py in __eq__(self, other)
#    1791     def __eq__(self, other):
#    1792         if getattr(other, "is_affine", False) and hasattr(other, "get_matrix"):
# -> 1793             return np.all(self.get_matrix() == other.get_matrix())
#    1794         return NotImplemented
#    1795
#
# <__array_function__ internals> in all(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py in all(a, axis, out, keepdims, where)
#    2448
#    2449     """
# -> 2450     return _wrapreduction(a, np.logical_and, 'all', axis, None, out,
#    2451                           keepdims=keepdims, where=where)
#    2452
#
# ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84                 return reduction(axis=axis, out=out, **passkwargs)
#      85
# ---> 86     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      87
#      88
#
# KeyboardInterrupt:
